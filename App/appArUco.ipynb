# %%
from moviepy import VideoFileClip
from IPython.display import Video
clip = VideoFileClip('../Applications/office_markers.mp4')
clip.write_videofile("temp_out.mp4",codec = "libx264")
Video('temp_out.mp4')
# Out:
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2avc1mp41'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1280, 720], 'bitrate': 2555, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 44100, 'bitrate': 1, 'metadata': {'Metadata': '', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 32.3, 'bitrate': 2559, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 2555, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number':
# ...

# %%
pip show moviepy
# Out:
# Name: moviepy
# Version: 2.1.2
# Summary: Video editing with Python
# Home-page:
# Author: Zulko 2024
# Author-email:
# License: MIT License
# Location: C:\Users\dell\miniconda3\envs\opencv-env\Lib\site-packages
# Requires: decorator, imageio, imageio_ffmpeg, numpy, pillow, proglog, python-dotenv
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import mime
import mimetypes
from IPython.display import Image

# %%
#Case -1 Image in Image
from IPython.display import Image
Image('../Applications/visuals/AR_image_in_image_Apollo-8-launch.jpg')

# %%
#Case - 2 Image in Video
from moviepy import VideoFileClip
clip = VideoFileClip('../Applications/visuals/AR_image_in_video_New_Zealand_Cove.mp4')
clip.write_videofile('temp_output.mp4',codec = 'libx264')
Video('temp_output.mp4',width=800)
# Out:
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf58.45.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [2560, 720], 'bitrate': 10547, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 32.3, 'bitrate': 10548, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [2560, 720], 'video_bitrate': 10547, 'video_fps': 30.0, 'video_duration': 32.3, 'video_n_frames': 968}
# ...

# %%
#Case 3 Video-In-Image
clip = VideoFileClip('../Applications/visuals/AR_video_in_image_boys_playing.mp4')
clip.write_videofile('temp_video2.mp4',codec='libx264')
Video('temp_video2.mp4',width=600)
# Out:
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf58.61.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [4000, 1500], 'bitrate': 16966, 'fps': 29.99, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 16.84, 'bitrate': 16968, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [4000, 1500], 'video_bitrate': 16966, 'video_fps': 29.99, 'video_duration': 16.84, 'video_n_frames': 505}
# ...

# %%
#Case 4 Video In Video
clip = VideoFileClip('../Applications/visuals/AR_video_in_video_horse_race.mp4')
clip.write_videofile('temp_video.mp4',codec = 'libx264')
Video('temp_video.mp4',width=800)
# Out:
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf58.61.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [2560, 720], 'bitrate': 11371, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 21.77, 'bitrate': 11373, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [2560, 720], 'video_bitrate': 11371, 'video_fps': 30.0, 'video_duration': 21.77, 'video_n_frames': 653}
# ...

# %%
mimetypes.init()

case1_img_in_img = ['../Applications/Apollo-8-launch.png','../Applications/office_markers.jpg']
case2_img_in_vide = ['../Applications/New_Zealand_Cove.jpg','../Applications/office_markers.mp4']
case3_vid_in_img = ['../Applications/boys_playing.mp4','../Applications/office_markers.jpg']
case4_vid_in_vid = ['../Applications/horse_race.mp4','../Applications/office_markers.mp4']

# %%
case
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 case
#
# NameError: name 'case' is not defined

# %%
case = case4_vid_in_vid

# %%
marker_ids = [23,25,30,33]

# %%
scaling_factor_x = 0.008
scaling_factor_y = 0.012

# %%
prefix = 'AR_'

# %%
class MediaSpec:
    def __init__(self, src, dst):
        self.src = src
        self.dst = dst

# %%
media_spec = MediaSpec(case[0],case[1])

# %%
src_input = media_spec.src

# %%
dst_output = media_spec.dst

# %%
src_input
# Out:
# '../Applications/horse_race.mp4'

# %%
mimetypes.guess_type(dst_output)
# Out:
# ('video/mp4', None)

# %%
mime_dst = mimetypes.guess_type(dst_output)[0]
if mime_dst != None:
    mime_dst = mime_dst.split('/')[0]
mime_src = mimetypes.guess_type(src_input)[0]
if mime_src != None:
    mime_src = mime_src.split('/')[0]

# %%
mime_dst
# Out:
# 'video'

# %%
if mime_dst == 'image':
    frame_dst = cv2.imread(dst_output)
elif mime_dst == 'video':
    cap_dst = cv2.VideoCapture(dst_output)
    fps_dst = cap_dst.get(cv2.CAP_PROP_FPS)
    width_dst = cap_dst.get(cv2.CAP_PROP_FRAME_WIDTH)
    height_dst = cap_dst.get(cv2.CAP_PROP_FRAME_HEIGHT)

# %%
print(fps_dst,width_dst,height_dst)
# Out:
# 30.00060469485082 1280.0 720.0

# %%
if mime_src == 'image':
    frame_src = cv2.imread(src_input)
elif mime_src == 'video':
    cap_src = cv2.VideoCapture(src_input)
    fps_src = cap_src.get(cv2.CAP_PROP_FPS)
    width_SRC = cap_src.get(cv2.CAP_PROP_FRAME_WIDTH)
    height_SRC = cap_src.get(cv2.CAP_PROP_FRAME_HEIGHT)

# %%
print(fps_src,width_SRC,height_SRC)
# Out:
# 30.00044865716909 1280.0 720.0

# %%
if (mime_src == 'video' or mime_dst == 'video'):
    output_file = prefix+str(mime_src)+'_in_'+str(mime_dst)+'_'+str(src_input[:-4]).split('/')[2] + '.mp4'
    if mime_dst == 'video':
        width = round(2 * cap_dst.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = round(cap_dst.get(cv2.CAP_PROP_FRAME_HEIGHT))
    else:
        width = round(2 * frame_dst.shape[1])
        height = round(frame_dat.shape[0])

    video_writer = cv2.VideoWriter(output_file, cv2.VideoWriter_fourcc(*'mp4v'), fps_src, (width, height))
else:
    output_file = prefix + 'image_in_image' + '_'+str(src_input[:-4]).split('/')[2] + '.jpg'

# %%
output_file
# Out:
# 'AR_video_in_video_horse_race.mp4'

# %%
def extract_pts(marker_ids, ids, corners):
    index = np.squeeze(np.where(ids == marker_ids[0]))
    ref_pt1 = np.squeeze(corners[index[0]])[0]

    index = np.squeeze(np.where(ids == marker_ids[1]))
    ref_pt2 = np.squeeze(corners[index[0]])[1]

    index = np.squeeze(np.where(ids == marker_ids[2]))
    ref_pt3 = np.squeeze(corners[index[0]])[2]

    index = np.squeeze(np.where(ids == marker_ids[3]))
    ref_pt4 = np.squeeze(corners[index[0]])[3]

    return ref_pt1, ref_pt2, ref_pt3, ref_pt4

# %%
def scale_dst_points(ref_pt1, ref_pt2, ref_pt3, ref_pt4, scaling_fac_x = 0.01, scaling_fac_y = 0.01):
    x_distance = np.linalg.norm(ref_pt1 - ref_pt2)
    y_distance = np.linalg.norm(ref_pt1 - ref_pt4)

    delta_x = round(scaling_fac_x * x_distance)
    delta_y = round(scaling_fac_y * y_distance)

    pts_dst = [[ref_pt1[0] - delta_x, ref_pt1[1] - delta_y]]
    pts_dst = pts_dst + [[ref_pt2[0] + delta_x, ref_pt2[1] - delta_y]]
    pts_dst = pts_dst + [[ref_pt3[0] + delta_x, ref_pt3[1] + delta_y]]
    pts_dst = pts_dst + [[ref_pt4[0] - delta_x, ref_pt4[1] + delta_y]]

    return pts_dst

# %%
src_has_frame = True
dst_has_frame = True

frame_count = 0
max_frames = 100
color = (255,255,255)

dictionary = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_6X6_250)

# %%
print('Processing Frames ....')

while src_has_frame & dst_has_frame:
    if mime_dst == 'video':
        dst_has_frame, dst_frame = cap_dst.read()
        if not dst_has_frame:
            break
    if mime_src == 'video':
        src_has_frame, src_frame = cap_src.read()
        if not src_has_frame:
            break
    corners, ids, rejected = cv2.aruco.detectMarkers(dst_frame, dictionary)

    ref_pt1, ref_pt2, ref_pt3, ref_pt4 = extract_pts(marker_ids, ids, corners)

    pts_dst = scale_dst_points(ref_pt1, ref_pt2, ref_pt3, ref_pt4, scaling_fac_x = scaling_factor_x,
                                                                      scaling_fac_y = scaling_factor_y)

    #pts_src = [[0,0],[src_frame.shape[1], 0],[src_frame.shape[1],src_frame.shape[0]],[0,src_frame.shape[0]]]
    pts_src = [[0,0], [src_frame.shape[1], 0], [src_frame.shape[1], src_frame.shape[0]], [0, src_frame.shape[0]]]

    pts_src_m = np.asarray(pts_src)
    pts_dst_m = np.asarray(pts_dst)

    h, mask = cv2.findHomography(pts_src_m,pts_dst_m,cv2.RANSAC)

    warped_image = cv2.warpPerspective(src_frame,h,(dst_frame.shape[1],dst_frame.shape[0]))
    mask = np.zeros([dst_frame.shape[0],dst_frame.shape[1]],dtype=np.uint8)

    cv2.fillConvexPoly(mask, np.int32([pts_dst_m]),(255,255,255),cv2.LINE_AA)

    warped_image = warped_image.astype(float)
    mask3 = np.zeros_like(warped_image)
    for i in range(0,3):
        mask3[:,:,i] = mask / 255

    frame_masked = cv2.multiply(dst_frame.astype(float), 1 - mask3)

    frame_out = cv2.add(warped_image, frame_masked)

    concatenated_output = cv2.hconcat([dst_frame.astype(float),frame_out])
    frame_w = concatenated_output.shape[1]
    frame_h = concatenated_output.shape[0]
    concatenated_output = cv2.line(concatenated_output, (int(frame_w / 2),0),
                                                        (int(frame_w / 2),frame_h),
                                                        color = color,
                                                           thickness = 8)

    if (mime_dst == 'image' and mime_src == 'image'):
        cv2.imwrite(output_file,concatenated_output.astype(np.uint8))
        break
    else:
        #video_writer.write(concatenated_output).astype(np.uint8)
        video_writer.write(concatenated_output.astype(np.uint8))

cv2.destroyAllWindows()
if 'video_writer' in locals():
    video_writer.release()
    print('Processing Completed, Video Writer released')
# Out:
# Processing Frames ....
# Processing Completed, Video Writer released

# %%
from moviepy import VideoFileClip

# %%
from IPython.display import Video

# %%
clip = VideoFileClip('AR_video_in_video_horse_race.mp4')
clip.write_videofile("temp_out_out.mp4",codec = "libx264")
Video('temp_out_out.mp4')
# Out:
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf58.76.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [2560, 720], 'bitrate': 11374, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 21.77, 'bitrate': 11375, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [2560, 720], 'video_bitrate': 11374, 'video_fps': 30.0, 'video_duration': 21.77, 'video_n_frames': 653}
# ...
